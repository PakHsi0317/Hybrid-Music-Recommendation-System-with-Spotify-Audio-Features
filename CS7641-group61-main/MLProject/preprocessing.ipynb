# %%
import pandas as pd
import numpy as np
from preprocessing import MusicDatasetPreprocessor

# %%
preprocessor = MusicDatasetPreprocessor()
preprocessor.load_spotify_features("./data/spotify_data.csv")
preprocessor.load_thisismyjam_data(
    jams_path="./data/jams.tsv",
    likes_path="./data/likes.tsv"
)
preprocessor.merge_datasets()

# %%
# if just preprocessed

# for supervised
final_data_with_features = preprocessor.final_dataset
print(final_data_with_features.columns)

# matrix for unsipervised
final_user_song_matrix = preprocessor.user_song_matrix
user_to_idx, idx_to_user, song_to_idx, idx_to_song = preprocessor.mappings

# %%
# if already preprocessed before
data_path = preprocessor.data_dir / "processed_music_data_no_negatives.csv"
final_dataset_before_negatives = preprocessor.load_processed_data(input_path=data_path)
preprocessor.create_sparse_matrix(final_dataset=final_dataset_before_negatives)
final_user_song_matrix = preprocessor.user_song_matrix
user_to_idx, idx_to_user, song_to_idx, idx_to_song = preprocessor.mappings


data_path = preprocessor.data_dir / "processed_music_data.csv"
final_data_with_features = preprocessor.load_processed_data(input_path=data_path)
